# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install split-folders[full]
import splitfolders 
# or import splitfolders
input_folder = "/content/drive/My Drive/Dataset_Raw/Lung_Opacity_vs_Normal"
output = "/content/drive/My Drive/Dataset_Clean/Lung_Opacity_vs_Normal" 
# where you want the split datasets saved. 
# one will be created if it does not exist or none is set

splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.75, .25)) 
# ratio of split are in order of train/val/test. 
# You can change to whatever you want. 
# For train/val sets only, you could do .75, .25 for example.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Copying files: 12024 files [10:48, 18.53 files/s]
