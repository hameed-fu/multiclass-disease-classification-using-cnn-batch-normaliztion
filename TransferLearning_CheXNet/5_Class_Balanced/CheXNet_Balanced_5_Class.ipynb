# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorboard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input

from tensorflow.keras.metrics import Precision, Accuracy
from tensorflow.keras.metrics import SensitivityAtSpecificity, SpecificityAtSensitivity
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint

import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

from tensorflow.keras.models import Model

# %%
img_width, img_height = 224, 224
# Set up the data generators
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory('/content/drive/MyDrive/Dataset_Clean/5_Dataset_Balanced/train', 
                                                    target_size=(img_width, img_height), batch_size=32, 
                                                    class_mode='categorical')

test_generator = test_datagen.flow_from_directory('/content/drive/MyDrive/Dataset_Clean/5_Dataset_Balanced/val', 
                                                  target_size=(img_width, img_height), batch_size=32, 
                                                  class_mode='categorical')
# Out:
# Found 2612 images belonging to 5 classes.
# Found 875 images belonging to 5 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0,
#  'Lung_Opacity': 1,
#  'Normal': 2,
#  'Tuberculosis': 3,
#  'Viral_Pneumonia': 4}

# %%
# Define the Keras TensorBoard callback.
logdir = "/content/drive/MyDrive/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# To save the training history
csv_logger = CSVLogger("/content/drive/MyDrive/Trainig_History.csv", append=True)

# %%
checkpoint_filepath = "/content/drive/MyDrive/CheXNet_5_class_balance.h5"
SAVE_BEST_ONLY = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', verbose=0, 
                                 save_best_only=True, mode='auto')

CALLBACKS = [tensorboard_callback, csv_logger, SAVE_BEST_ONLY]

# %%
from tensorflow.keras.applications import DenseNet121

image_shape= (224,224,3)
image_input= Input(shape=(224,224,3))
base=DenseNet121(include_top=False,input_tensor=image_input,input_shape=image_shape,pooling="avg")
pred=Dense(14,"sigmoid")(base.output)

chexnet_model=Model(inputs=base.input,outputs=pred)
# Load the pre-trained weights
chexnet_model.load_weights("/content/drive/MyDrive/Paper_Codes/CheXNet_Keras_0.3.0_weights.h5")

# %%
# Remove last 2 layers
final_chexnet_model=Model(inputs=chexnet_model.inputs,outputs=chexnet_model.layers[-2].output,name="Chexnet_model")
new_model = Sequential()
new_model.add(final_chexnet_model)
new_model.add(Dense(5,activation='softmax'))

# Compile the model
new_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', 'Precision', 'Recall', 'TruePositives',
                                                                          'TrueNegatives', 'FalsePositives', 'FalseNegatives', 
                                                                          tf.keras.metrics.SpecificityAtSensitivity(0.5), 
                                                                          tf.keras.metrics.SensitivityAtSpecificity(0.5)])
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Chexnet_model (Functional)  (None, 1024)              7037504
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 7,042,629
# Trainable params: 6,958,981
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(new_model,show_shapes=True,show_layer_names=True,to_file="chex.png")

# %%
history = new_model.fit(train_generator, epochs=50, validation_data=test_generator, callbacks=CALLBACKS)
# Out:
# Epoch 1/50
# 82/82 [==============================] - 143s 754ms/step - loss: 0.8077 - accuracy: 0.7247 - precision: 0.9066 - recall: 0.4721 - true_positives: 1233.0000 - true_negatives: 10321.0000 - false_positives: 127.0000 - false_negatives: 1379.0000 - specificity_at_sensitivity: 0.9853 - sensitivity_at_specificity: 0.9874 - val_loss: 1.0641 - val_accuracy: 0.5623 - val_precision: 0.6252 - val_recall: 0.4937 - val_true_positives: 432.0000 - val_true_negatives: 3241.0000 - val_false_positives: 259.0000 - val_false_negatives: 443.0000 - val_specificity_at_sensitivity: 0.9214 - val_sensitivity_at_specificity: 0.9589
# Epoch 2/50
# 82/82 [==============================] - 55s 668ms/step - loss: 0.3123 - accuracy: 0.8874 - precision: 0.9120 - recall: 0.8729 - true_positives: 2280.0000 - true_negatives: 10228.0000 - false_positives: 220.0000 - false_negatives: 332.0000 - specificity_at_sensitivity: 0.9989 - sensitivity_at_specificity: 0.9985 - val_loss: 0.6578 - val_accuracy: 0.7520 - val_precision: 0.8005 - val_recall: 0.6789 - val_true_positives: 594.0000 - val_true_negatives: 3352.0000 - val_false_positives: 148.0000 - val_false_negatives: 281.0000 - val_specificity_at_sensitivity: 0.9863 - val_sensitivity_at_specificity: 0.9863
# Epoch 3/50
# 82/82 [==============================] - 58s 706ms/step - loss: 0.2260 - accuracy: 0.9280 - precision: 0.9376 - recall: 0.9150 - true_positives: 2390.0000 - true_negatives: 10289.0000 - false_positives: 159.0000 - false_negatives: 222.0000 - specificity_at_sensitivity: 0.9995 - sensitivity_at_specificity: 0.9985 - val_loss: 0.6870 - val_accuracy: 0.7291 - val_precision: 0.7754 - val_recall: 0.6983 - val_true_positives: 611.0000 - val_true_negatives: 3323.0000 - val_false_positives: 177.0000 - val_false_negatives: 264.0000 - val_specificity_at_sensitivity: 0.9934 - val_sensitivity_at_specificity: 0.9943
# Epoch 4/50
# 82/82 [==============================] - 53s 644ms/step - loss: 0.1908 - accuracy: 0.9288 - precision: 0.9399 - recall: 0.9223 - true_positives: 2409.0000 - true_negatives: 10294.0000 - false_positives: 154.0000 - false_negatives: 203.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9989 - val_loss: 1.3214 - val_accuracy: 0.5486 - val_precision: 0.5524 - val_recall: 0.5303 - val_true_positives: 464.0000 - val_true_negatives: 3124.0000 - val_false_positives: 376.0000 - val_false_negatives: 411.0000 - val_specificity_at_sensitivity: 0.8991 - val_sensitivity_at_specificity: 0.9646
# Epoch 5/50
# 82/82 [==============================] - 55s 671ms/step - loss: 0.1646 - accuracy: 0.9468 - precision: 0.9524 - recall: 0.9414 - true_positives: 2459.0000 - true_negatives: 10325.0000 - false_positives: 123.0000 - false_negatives: 153.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3969 - val_accuracy: 0.8583 - val_precision: 0.8812 - val_recall: 0.8480 - val_true_positives: 742.0000 - val_true_negatives: 3400.0000 - val_false_positives: 100.0000 - val_false_negatives: 133.0000 - val_specificity_at_sensitivity: 0.9971 - val_sensitivity_at_specificity: 0.9886
# Epoch 6/50
# 82/82 [==============================] - 53s 638ms/step - loss: 0.1496 - accuracy: 0.9456 - precision: 0.9516 - recall: 0.9418 - true_positives: 2460.0000 - true_negatives: 10323.0000 - false_positives: 125.0000 - false_negatives: 152.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 1.0953 - val_accuracy: 0.6731 - val_precision: 0.6876 - val_recall: 0.6514 - val_true_positives: 570.0000 - val_true_negatives: 3241.0000 - val_false_positives: 259.0000 - val_false_negatives: 305.0000 - val_specificity_at_sensitivity: 0.9749 - val_sensitivity_at_specificity: 0.9566
# Epoch 7/50
# 82/82 [==============================] - 55s 674ms/step - loss: 0.1270 - accuracy: 0.9594 - precision: 0.9622 - recall: 0.9552 - true_positives: 2495.0000 - true_negatives: 10350.0000 - false_positives: 98.0000 - false_negatives: 117.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9973 - val_loss: 0.3423 - val_accuracy: 0.8994 - val_precision: 0.9038 - val_recall: 0.8914 - val_true_positives: 780.0000 - val_true_negatives: 3417.0000 - val_false_positives: 83.0000 - val_false_negatives: 95.0000 - val_specificity_at_sensitivity: 0.9983 - val_sensitivity_at_specificity: 0.9886
# Epoch 8/50
# 82/82 [==============================] - 55s 673ms/step - loss: 0.1150 - accuracy: 0.9629 - precision: 0.9683 - recall: 0.9583 - true_positives: 2503.0000 - true_negatives: 10366.0000 - false_positives: 82.0000 - false_negatives: 109.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9985 - val_loss: 0.2712 - val_accuracy: 0.8949 - val_precision: 0.9005 - val_recall: 0.8891 - val_true_positives: 778.0000 - val_true_negatives: 3414.0000 - val_false_positives: 86.0000 - val_false_negatives: 97.0000 - val_specificity_at_sensitivity: 0.9991 - val_sensitivity_at_specificity: 0.9931
# Epoch 9/50
# 82/82 [==============================] - 58s 701ms/step - loss: 0.0905 - accuracy: 0.9713 - precision: 0.9750 - recall: 0.9694 - true_positives: 2532.0000 - true_negatives: 10383.0000 - false_positives: 65.0000 - false_negatives: 80.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9989 - val_loss: 0.4865 - val_accuracy: 0.8400 - val_precision: 0.8489 - val_recall: 0.8286 - val_true_positives: 725.0000 - val_true_negatives: 3371.0000 - val_false_positives: 129.0000 - val_false_negatives: 150.0000 - val_specificity_at_sensitivity: 0.9977 - val_sensitivity_at_specificity: 0.9829
# Epoch 10/50
# 82/82 [==============================] - 53s 638ms/step - loss: 0.0859 - accuracy: 0.9705 - precision: 0.9712 - recall: 0.9682 - true_positives: 2529.0000 - true_negatives: 10373.0000 - false_positives: 75.0000 - false_negatives: 83.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9992 - val_loss: 1.3195 - val_accuracy: 0.7166 - val_precision: 0.7234 - val_recall: 0.7143 - val_true_positives: 625.0000 - val_true_negatives: 3261.0000 - val_false_positives: 239.0000 - val_false_negatives: 250.0000 - val_specificity_at_sensitivity: 0.9823 - val_sensitivity_at_specificity: 0.9120
# Epoch 11/50
# 82/82 [==============================] - 57s 698ms/step - loss: 0.0915 - accuracy: 0.9682 - precision: 0.9719 - recall: 0.9682 - true_positives: 2529.0000 - true_negatives: 10375.0000 - false_positives: 73.0000 - false_negatives: 83.0000 - specificity_at_sensitivity: 0.9998 - sensitivity_at_specificity: 0.9981 - val_loss: 0.5257 - val_accuracy: 0.8697 - val_precision: 0.8778 - val_recall: 0.8617 - val_true_positives: 754.0000 - val_true_negatives: 3395.0000 - val_false_positives: 105.0000 - val_false_negatives: 121.0000 - val_specificity_at_sensitivity: 0.9954 - val_sensitivity_at_specificity: 0.9714
# Epoch 12/50
# 82/82 [==============================] - 53s 643ms/step - loss: 0.0678 - accuracy: 0.9743 - precision: 0.9762 - recall: 0.9732 - true_positives: 2542.0000 - true_negatives: 10386.0000 - false_positives: 62.0000 - false_negatives: 70.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3331 - val_accuracy: 0.9006 - val_precision: 0.9070 - val_recall: 0.8914 - val_true_positives: 780.0000 - val_true_negatives: 3420.0000 - val_false_positives: 80.0000 - val_false_negatives: 95.0000 - val_specificity_at_sensitivity: 0.9980 - val_sensitivity_at_specificity: 0.9874
# Epoch 13/50
# 82/82 [==============================] - 53s 639ms/step - loss: 0.0705 - accuracy: 0.9766 - precision: 0.9781 - recall: 0.9743 - true_positives: 2545.0000 - true_negatives: 10391.0000 - false_positives: 57.0000 - false_negatives: 67.0000 - specificity_at_sensitivity: 0.9998 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3520 - val_accuracy: 0.9040 - val_precision: 0.9117 - val_recall: 0.8971 - val_true_positives: 785.0000 - val_true_negatives: 3424.0000 - val_false_positives: 76.0000 - val_false_negatives: 90.0000 - val_specificity_at_sensitivity: 0.9974 - val_sensitivity_at_specificity: 0.9851
# Epoch 14/50
# 82/82 [==============================] - 55s 672ms/step - loss: 0.0733 - accuracy: 0.9724 - precision: 0.9735 - recall: 0.9713 - true_positives: 2537.0000 - true_negatives: 10379.0000 - false_positives: 69.0000 - false_negatives: 75.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2085 - val_accuracy: 0.9326 - val_precision: 0.9356 - val_recall: 0.9291 - val_true_positives: 813.0000 - val_true_negatives: 3444.0000 - val_false_positives: 56.0000 - val_false_negatives: 62.0000 - val_specificity_at_sensitivity: 0.9989 - val_sensitivity_at_specificity: 0.9920
# Epoch 15/50
# 82/82 [==============================] - 52s 635ms/step - loss: 0.0609 - accuracy: 0.9793 - precision: 0.9804 - recall: 0.9778 - true_positives: 2554.0000 - true_negatives: 10397.0000 - false_positives: 51.0000 - false_negatives: 58.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2358 - val_accuracy: 0.9337 - val_precision: 0.9367 - val_recall: 0.9303 - val_true_positives: 814.0000 - val_true_negatives: 3445.0000 - val_false_positives: 55.0000 - val_false_negatives: 61.0000 - val_specificity_at_sensitivity: 0.9989 - val_sensitivity_at_specificity: 0.9897
# Epoch 16/50
# 82/82 [==============================] - 52s 632ms/step - loss: 0.0553 - accuracy: 0.9835 - precision: 0.9839 - recall: 0.9835 - true_positives: 2569.0000 - true_negatives: 10406.0000 - false_positives: 42.0000 - false_negatives: 43.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.6466 - val_accuracy: 0.8526 - val_precision: 0.8664 - val_recall: 0.8446 - val_true_positives: 739.0000 - val_true_negatives: 3386.0000 - val_false_positives: 114.0000 - val_false_negatives: 136.0000 - val_specificity_at_sensitivity: 0.9960 - val_sensitivity_at_specificity: 0.9623
# Epoch 17/50
# 82/82 [==============================] - 53s 640ms/step - loss: 0.0492 - accuracy: 0.9820 - precision: 0.9824 - recall: 0.9816 - true_positives: 2564.0000 - true_negatives: 10402.0000 - false_positives: 46.0000 - false_negatives: 48.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.4268 - val_accuracy: 0.8949 - val_precision: 0.8984 - val_recall: 0.8891 - val_true_positives: 778.0000 - val_true_negatives: 3412.0000 - val_false_positives: 88.0000 - val_false_negatives: 97.0000 - val_specificity_at_sensitivity: 0.9971 - val_sensitivity_at_specificity: 0.9771
# Epoch 18/50
# 82/82 [==============================] - 53s 640ms/step - loss: 0.0532 - accuracy: 0.9824 - precision: 0.9831 - recall: 0.9812 - true_positives: 2563.0000 - true_negatives: 10404.0000 - false_positives: 44.0000 - false_negatives: 49.0000 - specificity_at_sensitivity: 0.9996 - sensitivity_at_specificity: 0.9985 - val_loss: 0.3102 - val_accuracy: 0.9120 - val_precision: 0.9159 - val_recall: 0.9086 - val_true_positives: 795.0000 - val_true_negatives: 3427.0000 - val_false_positives: 73.0000 - val_false_negatives: 80.0000 - val_specificity_at_sensitivity: 0.9986 - val_sensitivity_at_specificity: 0.9874
# Epoch 19/50
# 82/82 [==============================] - 52s 636ms/step - loss: 0.0803 - accuracy: 0.9694 - precision: 0.9720 - recall: 0.9686 - true_positives: 2530.0000 - true_negatives: 10375.0000 - false_positives: 73.0000 - false_negatives: 82.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9992 - val_loss: 0.7527 - val_accuracy: 0.8023 - val_precision: 0.8116 - val_recall: 0.7977 - val_true_positives: 698.0000 - val_true_negatives: 3338.0000 - val_false_positives: 162.0000 - val_false_negatives: 177.0000 - val_specificity_at_sensitivity: 0.9920 - val_sensitivity_at_specificity: 0.9589
# Epoch 20/50
# 82/82 [==============================] - 53s 640ms/step - loss: 0.0585 - accuracy: 0.9820 - precision: 0.9827 - recall: 0.9809 - true_positives: 2562.0000 - true_negatives: 10403.0000 - false_positives: 45.0000 - false_negatives: 50.0000 - specificity_at_sensitivity: 0.9996 - sensitivity_at_specificity: 0.9977 - val_loss: 0.3578 - val_accuracy: 0.9131 - val_precision: 0.9162 - val_recall: 0.9120 - val_true_positives: 798.0000 - val_true_negatives: 3427.0000 - val_false_positives: 73.0000 - val_false_negatives: 77.0000 - val_specificity_at_sensitivity: 0.9980 - val_sensitivity_at_specificity: 0.9817
# Epoch 21/50
# 82/82 [==============================] - 52s 636ms/step - loss: 0.0393 - accuracy: 0.9855 - precision: 0.9858 - recall: 0.9847 - true_positives: 2572.0000 - true_negatives: 10411.0000 - false_positives: 37.0000 - false_negatives: 40.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3749 - val_accuracy: 0.9074 - val_precision: 0.9125 - val_recall: 0.9063 - val_true_positives: 793.0000 - val_true_negatives: 3424.0000 - val_false_positives: 76.0000 - val_false_negatives: 82.0000 - val_specificity_at_sensitivity: 0.9960 - val_sensitivity_at_specificity: 0.9737
# Epoch 22/50
# 82/82 [==============================] - 53s 640ms/step - loss: 0.0379 - accuracy: 0.9862 - precision: 0.9881 - recall: 0.9858 - true_positives: 2575.0000 - true_negatives: 10417.0000 - false_positives: 31.0000 - false_negatives: 37.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.4049 - val_accuracy: 0.9051 - val_precision: 0.9092 - val_recall: 0.9040 - val_true_positives: 791.0000 - val_true_negatives: 3421.0000 - val_false_positives: 79.0000 - val_false_negatives: 84.0000 - val_specificity_at_sensitivity: 0.9963 - val_sensitivity_at_specificity: 0.9737
# Epoch 23/50
# 82/82 [==============================] - 52s 636ms/step - loss: 0.0378 - accuracy: 0.9877 - precision: 0.9881 - recall: 0.9870 - true_positives: 2578.0000 - true_negatives: 10417.0000 - false_positives: 31.0000 - false_negatives: 34.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 0.7192 - val_accuracy: 0.8069 - val_precision: 0.8232 - val_recall: 0.8034 - val_true_positives: 703.0000 - val_true_negatives: 3349.0000 - val_false_positives: 151.0000 - val_false_negatives: 172.0000 - val_specificity_at_sensitivity: 0.9966 - val_sensitivity_at_specificity: 0.9589
# Epoch 24/50
# 82/82 [==============================] - 52s 634ms/step - loss: 0.0418 - accuracy: 0.9832 - precision: 0.9831 - recall: 0.9812 - true_positives: 2563.0000 - true_negatives: 10404.0000 - false_positives: 44.0000 - false_negatives: 49.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9029 - val_precision: 0.9057 - val_recall: 0.9006 - val_true_positives: 788.0000 - val_true_negatives: 3418.0000 - val_false_positives: 82.0000 - val_false_negatives: 87.0000 - val_specificity_at_sensitivity: 0.9974 - val_sensitivity_at_specificity: 0.9794
# Epoch 25/50
# 82/82 [==============================] - 52s 637ms/step - loss: 0.0411 - accuracy: 0.9855 - precision: 0.9869 - recall: 0.9843 - true_positives: 2571.0000 - true_negatives: 10414.0000 - false_positives: 34.0000 - false_negatives: 41.0000 - specificity_at_sensitivity: 0.9998 - sensitivity_at_specificity: 0.9992 - val_loss: 0.4760 - val_accuracy: 0.8811 - val_precision: 0.8848 - val_recall: 0.8777 - val_true_positives: 768.0000 - val_true_negatives: 3400.0000 - val_false_positives: 100.0000 - val_false_negatives: 107.0000 - val_specificity_at_sensitivity: 0.9960 - val_sensitivity_at_specificity: 0.9714
# Epoch 26/50
# 82/82 [==============================] - 52s 635ms/step - loss: 0.0526 - accuracy: 0.9816 - precision: 0.9842 - recall: 0.9805 - true_positives: 2561.0000 - true_negatives: 10407.0000 - false_positives: 41.0000 - false_negatives: 51.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3929 - val_accuracy: 0.8869 - val_precision: 0.8895 - val_recall: 0.8834 - val_true_positives: 773.0000 - val_true_negatives: 3404.0000 - val_false_positives: 96.0000 - val_false_negatives: 102.0000 - val_specificity_at_sensitivity: 0.9980 - val_sensitivity_at_specificity: 0.9874
# Epoch 27/50
# 82/82 [==============================] - 53s 642ms/step - loss: 0.0390 - accuracy: 0.9866 - precision: 0.9870 - recall: 0.9855 - true_positives: 2574.0000 - true_negatives: 10414.0000 - false_positives: 34.0000 - false_negatives: 38.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9992 - val_loss: 0.2639 - val_accuracy: 0.9383 - val_precision: 0.9403 - val_recall: 0.9360 - val_true_positives: 819.0000 - val_true_negatives: 3448.0000 - val_false_positives: 52.0000 - val_false_negatives: 56.0000 - val_specificity_at_sensitivity: 0.9974 - val_sensitivity_at_specificity: 0.9863
# Epoch 28/50
# 82/82 [==============================] - 52s 636ms/step - loss: 0.0415 - accuracy: 0.9839 - precision: 0.9839 - recall: 0.9832 - true_positives: 2568.0000 - true_negatives: 10406.0000 - false_positives: 42.0000 - false_negatives: 44.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3423 - val_accuracy: 0.9211 - val_precision: 0.9241 - val_recall: 0.9189 - val_true_positives: 804.0000 - val_true_negatives: 3434.0000 - val_false_positives: 66.0000 - val_false_negatives: 71.0000 - val_specificity_at_sensitivity: 0.9971 - val_sensitivity_at_specificity: 0.9829
# Epoch 29/50
# 82/82 [==============================] - 52s 631ms/step - loss: 0.0243 - accuracy: 0.9927 - precision: 0.9931 - recall: 0.9927 - true_positives: 2593.0000 - true_negatives: 10430.0000 - false_positives: 18.0000 - false_negatives: 19.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.4119 - val_accuracy: 0.9200 - val_precision: 0.9211 - val_recall: 0.9200 - val_true_positives: 805.0000 - val_true_negatives: 3431.0000 - val_false_positives: 69.0000 - val_false_negatives: 70.0000 - val_specificity_at_sensitivity: 0.9937 - val_sensitivity_at_specificity: 0.9726
# Epoch 30/50
# 82/82 [==============================] - 52s 637ms/step - loss: 0.0240 - accuracy: 0.9923 - precision: 0.9931 - recall: 0.9920 - true_positives: 2591.0000 - true_negatives: 10430.0000 - false_positives: 18.0000 - false_negatives: 21.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9394 - val_precision: 0.9412 - val_recall: 0.9337 - val_true_positives: 817.0000 - val_true_negatives: 3449.0000 - val_false_positives: 51.0000 - val_false_negatives: 58.0000 - val_specificity_at_sensitivity: 0.9980 - val_sensitivity_at_specificity: 0.9874
# Epoch 31/50
# 82/82 [==============================] - 52s 630ms/step - loss: 0.0338 - accuracy: 0.9874 - precision: 0.9885 - recall: 0.9866 - true_positives: 2577.0000 - true_negatives: 10418.0000 - false_positives: 30.0000 - false_negatives: 35.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.8530 - val_accuracy: 0.8366 - val_precision: 0.8375 - val_recall: 0.8366 - val_true_positives: 732.0000 - val_true_negatives: 3358.0000 - val_false_positives: 142.0000 - val_false_negatives: 143.0000 - val_specificity_at_sensitivity: 0.9886 - val_sensitivity_at_specificity: 0.9440
# Epoch 32/50
# 82/82 [==============================] - 52s 628ms/step - loss: 0.0240 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9912 - true_positives: 2589.0000 - true_negatives: 10427.0000 - false_positives: 21.0000 - false_negatives: 23.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.9061 - val_accuracy: 0.7851 - val_precision: 0.7889 - val_recall: 0.7817 - val_true_positives: 684.0000 - val_true_negatives: 3317.0000 - val_false_positives: 183.0000 - val_false_negatives: 191.0000 - val_specificity_at_sensitivity: 0.9917 - val_sensitivity_at_specificity: 0.9451
# Epoch 33/50
# 82/82 [==============================] - 56s 675ms/step - loss: 0.0320 - accuracy: 0.9889 - precision: 0.9893 - recall: 0.9889 - true_positives: 2583.0000 - true_negatives: 10420.0000 - false_positives: 28.0000 - false_negatives: 29.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9992 - val_loss: 0.1832 - val_accuracy: 0.9520 - val_precision: 0.9542 - val_recall: 0.9520 - val_true_positives: 833.0000 - val_true_negatives: 3460.0000 - val_false_positives: 40.0000 - val_false_negatives: 42.0000 - val_specificity_at_sensitivity: 0.9983 - val_sensitivity_at_specificity: 0.9886
# Epoch 34/50
# 82/82 [==============================] - 53s 637ms/step - loss: 0.0247 - accuracy: 0.9904 - precision: 0.9904 - recall: 0.9900 - true_positives: 2586.0000 - true_negatives: 10423.0000 - false_positives: 25.0000 - false_negatives: 26.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9051 - val_precision: 0.9077 - val_recall: 0.8994 - val_true_positives: 787.0000 - val_true_negatives: 3420.0000 - val_false_positives: 80.0000 - val_false_negatives: 88.0000 - val_specificity_at_sensitivity: 0.9983 - val_sensitivity_at_specificity: 0.9771
# Epoch 35/50
# 82/82 [==============================] - 53s 645ms/step - loss: 0.0211 - accuracy: 0.9912 - precision: 0.9916 - recall: 0.9908 - true_positives: 2588.0000 - true_negatives: 10426.0000 - false_positives: 22.0000 - false_negatives: 24.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9246 - val_precision: 0.9246 - val_recall: 0.9246 - val_true_positives: 809.0000 - val_true_negatives: 3434.0000 - val_false_positives: 66.0000 - val_false_negatives: 66.0000 - val_specificity_at_sensitivity: 0.9974 - val_sensitivity_at_specificity: 0.9817
# Epoch 36/50
# 82/82 [==============================] - 53s 645ms/step - loss: 0.0240 - accuracy: 0.9908 - precision: 0.9916 - recall: 0.9904 - true_positives: 2587.0000 - true_negatives: 10426.0000 - false_positives: 22.0000 - false_negatives: 25.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3232 - val_accuracy: 0.9303 - val_precision: 0.9335 - val_recall: 0.9303 - val_true_positives: 814.0000 - val_true_negatives: 3442.0000 - val_false_positives: 58.0000 - val_false_negatives: 61.0000 - val_specificity_at_sensitivity: 0.9974 - val_sensitivity_at_specificity: 0.9817
# Epoch 37/50
# 82/82 [==============================] - 53s 642ms/step - loss: 0.0197 - accuracy: 0.9923 - precision: 0.9927 - recall: 0.9923 - true_positives: 2592.0000 - true_negatives: 10429.0000 - false_positives: 19.0000 - false_negatives: 20.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9303 - val_precision: 0.9301 - val_recall: 0.9280 - val_true_positives: 812.0000 - val_true_negatives: 3439.0000 - val_false_positives: 61.0000 - val_false_negatives: 63.0000 - val_specificity_at_sensitivity: 0.9951 - val_sensitivity_at_specificity: 0.9794
# Epoch 38/50
# 82/82 [==============================] - 53s 646ms/step - loss: 0.0216 - accuracy: 0.9927 - precision: 0.9931 - recall: 0.9927 - true_positives: 2593.0000 - true_negatives: 10430.0000 - false_positives: 18.0000 - false_negatives: 19.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.4272 - val_accuracy: 0.8777 - val_precision: 0.8794 - val_recall: 0.8754 - val_true_positives: 766.0000 - val_true_negatives: 3395.0000 - val_false_positives: 105.0000 - val_false_negatives: 109.0000 - val_specificity_at_sensitivity: 0.9960 - val_sensitivity_at_specificity: 0.9771
# Epoch 39/50
# 82/82 [==============================] - 53s 639ms/step - loss: 0.0383 - accuracy: 0.9855 - precision: 0.9862 - recall: 0.9855 - true_positives: 2574.0000 - true_negatives: 10412.0000 - false_positives: 36.0000 - false_negatives: 38.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.4194 - val_accuracy: 0.9029 - val_precision: 0.9047 - val_recall: 0.9006 - val_true_positives: 788.0000 - val_true_negatives: 3417.0000 - val_false_positives: 83.0000 - val_false_negatives: 87.0000 - val_specificity_at_sensitivity: 0.9969 - val_sensitivity_at_specificity: 0.9783
# Epoch 40/50
# 82/82 [==============================] - 53s 639ms/step - loss: 0.0474 - accuracy: 0.9855 - precision: 0.9862 - recall: 0.9855 - true_positives: 2574.0000 - true_negatives: 10412.0000 - false_positives: 36.0000 - false_negatives: 38.0000 - specificity_at_sensitivity: 0.9997 - sensitivity_at_specificity: 0.9985 - val_loss: 1.1115 - val_accuracy: 0.7611 - val_precision: 0.7626 - val_recall: 0.7600 - val_true_positives: 665.0000 - val_true_negatives: 3293.0000 - val_false_positives: 207.0000 - val_false_negatives: 210.0000 - val_specificity_at_sensitivity: 0.9803 - val_sensitivity_at_specificity: 0.9154
# Epoch 41/50
# 82/82 [==============================] - 52s 630ms/step - loss: 0.0421 - accuracy: 0.9866 - precision: 0.9870 - recall: 0.9866 - true_positives: 2577.0000 - true_negatives: 10414.0000 - false_positives: 34.0000 - false_negatives: 35.0000 - specificity_at_sensitivity: 0.9997 - sensitivity_at_specificity: 0.9985 - val_loss: 0.2924 - val_accuracy: 0.9314 - val_precision: 0.9345 - val_recall: 0.9291 - val_true_positives: 813.0000 - val_true_negatives: 3443.0000 - val_false_positives: 57.0000 - val_false_negatives: 62.0000 - val_specificity_at_sensitivity: 0.9963 - val_sensitivity_at_specificity: 0.9806
# Epoch 42/50
# 82/82 [==============================] - 53s 644ms/step - loss: 0.0454 - accuracy: 0.9828 - precision: 0.9828 - recall: 0.9824 - true_positives: 2566.0000 - true_negatives: 10403.0000 - false_positives: 45.0000 - false_negatives: 46.0000 - specificity_at_sensitivity: 0.9998 - sensitivity_at_specificity: 0.9992 - val_loss: 0.4570 - val_accuracy: 0.8960 - val_precision: 0.8989 - val_recall: 0.8937 - val_true_positives: 782.0000 - val_true_negatives: 3412.0000 - val_false_positives: 88.0000 - val_false_negatives: 93.0000 - val_specificity_at_sensitivity: 0.9960 - val_sensitivity_at_specificity: 0.9737
# Epoch 43/50
# 82/82 [==============================] - 57s 697ms/step - loss: 0.0369 - accuracy: 0.9847 - precision: 0.9862 - recall: 0.9843 - true_positives: 2571.0000 - true_negatives: 10412.0000 - false_positives: 36.0000 - false_negatives: 41.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.5450 - val_accuracy: 0.8949 - val_precision: 0.8959 - val_recall: 0.8949 - val_true_positives: 783.0000 - val_true_negatives: 3409.0000 - val_false_positives: 91.0000 - val_false_negatives: 92.0000 - val_specificity_at_sensitivity: 0.9929 - val_sensitivity_at_specificity: 0.9634
# Epoch 44/50
# 82/82 [==============================] - 53s 643ms/step - loss: 0.0277 - accuracy: 0.9931 - precision: 0.9931 - recall: 0.9927 - true_positives: 2593.0000 - true_negatives: 10430.0000 - false_positives: 18.0000 - false_negatives: 19.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2147 - val_accuracy: 0.9394 - val_precision: 0.9394 - val_recall: 0.9383 - val_true_positives: 821.0000 - val_true_negatives: 3447.0000 - val_false_positives: 53.0000 - val_false_negatives: 54.0000 - val_specificity_at_sensitivity: 0.9986 - val_sensitivity_at_specificity: 0.9931
# Epoch 45/50
# 82/82 [==============================] - 53s 641ms/step - loss: 0.0388 - accuracy: 0.9874 - precision: 0.9874 - recall: 0.9870 - true_positives: 2578.0000 - true_negatives: 10415.0000 - false_positives: 33.0000 - false_negatives: 34.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 0.6598 - val_accuracy: 0.8606 - val_precision: 0.8664 - val_recall: 0.8594 - val_true_positives: 752.0000 - val_true_negatives: 3384.0000 - val_false_positives: 116.0000 - val_false_negatives: 123.0000 - val_specificity_at_sensitivity: 0.9931 - val_sensitivity_at_specificity: 0.9634
# Epoch 46/50
# 82/82 [==============================] - 53s 643ms/step - loss: 0.0278 - accuracy: 0.9912 - precision: 0.9916 - recall: 0.9912 - true_positives: 2589.0000 - true_negatives: 10426.0000 - false_positives: 22.0000 - false_negatives: 23.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 0.9996 - val_loss: 0.2992 - val_accuracy: 0.9349 - val_precision: 0.9370 - val_recall: 0.9349 - val_true_positives: 818.0000 - val_true_negatives: 3445.0000 - val_false_positives: 55.0000 - val_false_negatives: 57.0000 - val_specificity_at_sensitivity: 0.9954 - val_sensitivity_at_specificity: 0.9783
# Epoch 47/50
# 82/82 [==============================] - 53s 642ms/step - loss: 0.0176 - accuracy: 0.9927 - precision: 0.9935 - recall: 0.9923 - true_positives: 2592.0000 - true_negatives: 10431.0000 - false_positives: 17.0000 - false_negatives: 20.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.4423 - val_accuracy: 0.9200 - val_precision: 0.9220 - val_recall: 0.9189 - val_true_positives: 804.0000 - val_true_negatives: 3432.0000 - val_false_positives: 68.0000 - val_false_negatives: 71.0000 - val_specificity_at_sensitivity: 0.9934 - val_sensitivity_at_specificity: 0.9669
# Epoch 48/50
# 82/82 [==============================] - 53s 644ms/step - loss: 0.0315 - accuracy: 0.9893 - precision: 0.9897 - recall: 0.9889 - true_positives: 2583.0000 - true_negatives: 10421.0000 - false_positives: 27.0000 - false_negatives: 29.0000 - specificity_at_sensitivity: 0.9999 - sensitivity_at_specificity: 0.9996 - val_loss: 0.3026 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_true_positives: 818.0000 - val_true_negatives: 3443.0000 - val_false_positives: 57.0000 - val_false_negatives: 57.0000 - val_specificity_at_sensitivity: 0.9966 - val_sensitivity_at_specificity: 0.9806
# Epoch 49/50
# 82/82 [==============================] - 53s 642ms/step - loss: 0.0334 - accuracy: 0.9881 - precision: 0.9893 - recall: 0.9881 - true_positives: 2581.0000 - true_negatives: 10420.0000 - false_positives: 28.0000 - false_negatives: 31.0000 - specificity_at_sensitivity: 0.9998 - sensitivity_at_specificity: 0.9992 - val_loss: 0.3283 - val_accuracy: 0.9211 - val_precision: 0.9220 - val_recall: 0.9189 - val_true_positives: 804.0000 - val_true_negatives: 3432.0000 - val_false_positives: 68.0000 - val_false_negatives: 71.0000 - val_specificity_at_sensitivity: 0.9971 - val_sensitivity_at_specificity: 0.9829
# Epoch 50/50
# 82/82 [==============================] - 54s 654ms/step - loss: 0.0251 - accuracy: 0.9897 - precision: 0.9908 - recall: 0.9893 - true_positives: 2584.0000 - true_negatives: 10424.0000 - false_positives: 24.0000 - false_negatives: 28.0000 - specificity_at_sensitivity: 1.0000 - sensitivity_at_specificity: 1.0000 - val_loss: 0.7749 - val_accuracy: 0.8434 - val_precision: 0.8468 - val_recall: 0.8400 - val_true_positives: 735.0000 - val_true_negatives: 3367.0000 - val_false_positives: 133.0000 - val_false_negatives: 140.0000 - val_specificity_at_sensitivity: 0.9929 - val_sensitivity_at_specificity: 0.9474

# %%
# Evaluate the model
loss, accuracy,*_ = new_model.evaluate(test_generator)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 28/28 [==============================] - 5s 163ms/step - loss: 0.7749 - accuracy: 0.8434 - precision: 0.8468 - recall: 0.8400 - true_positives: 735.0000 - true_negatives: 3367.0000 - false_positives: 133.0000 - false_negatives: 140.0000 - specificity_at_sensitivity: 0.9929 - sensitivity_at_specificity: 0.9474
# Test Loss: 0.7748635411262512
# Test Accuracy: 0.8434285521507263

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

y_pred = new_model.predict_generator(test_generator, steps=len(test_generator))
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes
cm = confusion_matrix(y_true, y_pred_classes)


sns.heatmap(cm, annot=True, cmap="Blues")
plt.show()
# Out:
# <ipython-input-11-a379743ec994>:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = new_model.predict_generator(test_generator, steps=len(test_generator))
