# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from keras.utils import to_categorical

# Define the directory where the folders of images are located
directory = '/content/drive/My Drive/Dataset_Raw/Covid_vs_Normal/'

# Define the desired size for the images
image_size = (28, 28)

# Define the mapping of folder names to numerical labels
class_dict = {'Covid': 0, 'Normal': 1}

# Define the number of classes
num_classes = len(class_dict)

# Load the images and preprocess them
data = []
labels = []
for class_name in os.listdir(directory):
    class_directory = os.path.join(directory, class_name)
    if class_name in class_dict:
        class_label = class_dict[class_name]
        for filename in os.listdir(class_directory):
            if filename.endswith('.png'):
                img = cv2.imread(os.path.join(class_directory, filename))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert to grayscale
                img = cv2.resize(img, image_size)  # resize the image
                data.append(img)
                labels.append(class_label)

# Convert the data and labels to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Reshape the data to have a single channel (grayscale)
data = np.reshape(data, (*data.shape, 1))

# Convert the labels to one-hot encoding
labels = to_categorical(labels, num_classes)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.linear_model import LogisticRegression

# Define the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model on the training set
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Extract features from the CNN model for the training and testing sets
train_features = model.predict(x_train)
test_features = model.predict(x_test)

clf = LogisticRegression()
clf.fit(train_features, np.argmax(y_train, axis=1))
# Out:
# Epoch 1/10
# 95/95 [==============================] - 6s 48ms/step - loss: 1.0567 - accuracy: 0.9227 - val_loss: 0.1696 - val_accuracy: 0.9434
# Epoch 2/10
# 95/95 [==============================] - 5s 49ms/step - loss: 0.1424 - accuracy: 0.9569 - val_loss: 0.1404 - val_accuracy: 0.9487
# Epoch 3/10
# 95/95 [==============================] - 3s 35ms/step - loss: 0.1272 - accuracy: 0.9569 - val_loss: 0.1483 - val_accuracy: 0.9355
# Epoch 4/10
# 95/95 [==============================] - 3s 37ms/step - loss: 0.1057 - accuracy: 0.9661 - val_loss: 0.1336 - val_accuracy: 0.9500
# Epoch 5/10
# 95/95 [==============================] - 5s 53ms/step - loss: 0.0907 - accuracy: 0.9664 - val_loss: 0.1174 - val_accuracy: 0.9579
# Epoch 6/10
# 95/95 [==============================] - 4s 40ms/step - loss: 0.0830 - accuracy: 0.9730 - val_loss: 0.1212 - val_accuracy: 0.9513
# Epoch 7/10
# 95/95 [==============================] - 3s 34ms/step - loss: 0.0838 - accuracy: 0.9714 - val_loss: 0.1383 - val_accuracy: 0.9513
# Epoch 8/10
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0718 - accuracy: 0.9763 - val_loss: 0.1020 - val_accuracy: 0.9618
# Epoch 9/10
# 95/95 [==============================] - 5s 57ms/step - loss: 0.0694 - accuracy: 0.9753 - val_loss: 0.1545 - val_accuracy: 0.9513
# Epoch 10/10
# 95/95 [==============================] - 3s 35ms/step - loss: 0.0600 - accuracy: 0.9816 - val_loss: 0.0986 - val_accuracy: 0.9592
# 95/95 [==============================] - 1s 10ms/step
# 24/24 [==============================] - 0s 10ms/step
# LogisticRegression()

# %%
accuracy = clf.score(test_features, np.argmax(y_test, axis=1))
print('Logistic Regression accuracy:', accuracy)
# Out:
# Logistic Regression accuracy: 0.9605263157894737
