# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from keras.utils import to_categorical

# Define the directory where the folders of images are located
directory = '/content/drive/My Drive/Dataset_Raw/Tuberculosis_vs_Normal/'

# Define the desired size for the images
image_size = (28, 28)

# Define the mapping of folder names to numerical labels
class_dict = {'Normal': 0, 'Tuberculosis': 1}

# Define the number of classes
num_classes = len(class_dict)

# Load the images and preprocess them
data = []
labels = []
for class_name in os.listdir(directory):
    class_directory = os.path.join(directory, class_name)
    if class_name in class_dict:
        class_label = class_dict[class_name]
        for filename in os.listdir(class_directory):
            if filename.endswith('.png'):
                img = cv2.imread(os.path.join(class_directory, filename))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # convert to grayscale
                img = cv2.resize(img, image_size)  # resize the image
                data.append(img)
                labels.append(class_label)

# Convert the data and labels to numpy arrays
data = np.array(data)
labels = np.array(labels)

# Reshape the data to have a single channel (grayscale)
data = np.reshape(data, (*data.shape, 1))

# Convert the labels to one-hot encoding
labels = to_categorical(labels, num_classes)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.naive_bayes import GaussianNB

# Define the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the CNN model on the training set
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Extract features from the CNN model for the training and testing sets
train_features = model.predict(x_train)
test_features = model.predict(x_test)

nb = GaussianNB()
nb.fit(train_features, np.argmax(y_train, axis=1))
# Out:
# Epoch 1/10
# 35/35 [==============================] - 4s 67ms/step - loss: 1.2678 - accuracy: 0.7009 - val_loss: 0.4194 - val_accuracy: 0.8000
# Epoch 2/10
# 35/35 [==============================] - 1s 34ms/step - loss: 0.3188 - accuracy: 0.8696 - val_loss: 0.2431 - val_accuracy: 0.9143
# Epoch 3/10
# 35/35 [==============================] - 1s 43ms/step - loss: 0.2394 - accuracy: 0.9009 - val_loss: 0.2202 - val_accuracy: 0.9214
# Epoch 4/10
# 35/35 [==============================] - 2s 52ms/step - loss: 0.2419 - accuracy: 0.9009 - val_loss: 0.2051 - val_accuracy: 0.9250
# Epoch 5/10
# 35/35 [==============================] - 1s 34ms/step - loss: 0.1716 - accuracy: 0.9348 - val_loss: 0.1979 - val_accuracy: 0.9357
# Epoch 6/10
# 35/35 [==============================] - 1s 34ms/step - loss: 0.1328 - accuracy: 0.9616 - val_loss: 0.1930 - val_accuracy: 0.9321
# Epoch 7/10
# 35/35 [==============================] - 1s 34ms/step - loss: 0.1209 - accuracy: 0.9571 - val_loss: 0.1813 - val_accuracy: 0.9214
# Epoch 8/10
# 35/35 [==============================] - 1s 34ms/step - loss: 0.1015 - accuracy: 0.9661 - val_loss: 0.2449 - val_accuracy: 0.9036
# Epoch 9/10
# 35/35 [==============================] - 2s 51ms/step - loss: 0.1097 - accuracy: 0.9580 - val_loss: 0.2027 - val_accuracy: 0.9321
# Epoch 10/10
# 35/35 [==============================] - 2s 60ms/step - loss: 0.0701 - accuracy: 0.9768 - val_loss: 0.2558 - val_accuracy: 0.8964
# 35/35 [==============================] - 0s 9ms/step
# 9/9 [==============================] - 0s 10ms/step
# GaussianNB()

# %%
accuracy = nb.score(test_features, np.argmax(y_test, axis=1))
print('Naive Bayes classifier accuracy:', accuracy)
# Out:
# Naive Bayes classifier accuracy: 0.95
